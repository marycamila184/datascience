# %%
import pandas as pd
import unicodedata
import geopandas as gpd
import geopy
from geopy.geocoders import Photon
from geopy.extra.rate_limiter import RateLimiter
import matplotlib.pyplot as plt
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-179-c942ffc6c0df> in <module>
#       6 from geopy.extra.rate_limiter import RateLimiter
#       7 import matplotlib.pyplot as plt
# ----> 8 import folium
#
# ModuleNotFoundError: No module named 'folium'

# %%
raw_data = pd.read_csv("2019-10-01_sigesguarda_-_Base_de_Dados-limpo.csv")
display(raw_data.head(n=5))
display(raw_data.info())
# Out:
#   ATENDIMENTO_BAIRRO_NOME NATUREZA1_DESCRICAO   SUBCATEGORIA1_DESCRICAO  \
# 0                     cic             alarmes         disparo de alarme
# 1              fazendinha               roubo                transeunte
# 2                 uberaba             animais  cão solto em via pública
# 3           sítio cercado             animais  cão solto em via pública
# 4               tatuquara             alarmes         disparo de alarme
#
#        OCORRENCIA_DATA ORIGEM_CHAMADO_DESCRICAO REGIONAL_FATO_NOME
# 0  2009-01-01 15:14:00                     SIGA                cic
# 1  2009-01-01 15:22:00                      153             portão
# 2  2009-01-01 15:59:00                      156             cajuru
# 3  2009-01-01 16:13:00                      156        bairro novo
# 4  2009-01-01 16:29:00                     SIGA        pinheirinho
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255916 entries, 0 to 255915
# Data columns (total 6 columns):
# ATENDIMENTO_BAIRRO_NOME     255916 non-null object
# NATUREZA1_DESCRICAO         255916 non-null object
# SUBCATEGORIA1_DESCRICAO     255916 non-null object
# OCORRENCIA_DATA             255916 non-null object
# ORIGEM_CHAMADO_DESCRICAO    255916 non-null object
# REGIONAL_FATO_NOME          255916 non-null object
# dtypes: object(6)
# memory usage: 11.7+ MB
# None

# %%
raw_data['ADDRESS_FINAL'] = raw_data['ATENDIMENTO_BAIRRO_NOME'].astype(str) + ', Curitiba, Parana, Brazil'   
raw_data.head()
# Out:
#   ATENDIMENTO_BAIRRO_NOME NATUREZA1_DESCRICAO   SUBCATEGORIA1_DESCRICAO  \
# 0                     cic             alarmes         disparo de alarme
# 1              fazendinha               roubo                transeunte
# 2                 uberaba             animais  cão solto em via pública
# 3           sítio cercado             animais  cão solto em via pública
# 4               tatuquara             alarmes         disparo de alarme
#
#        OCORRENCIA_DATA ORIGEM_CHAMADO_DESCRICAO REGIONAL_FATO_NOME  \
# 0  2009-01-01 15:14:00                     SIGA                cic
# 1  2009-01-01 15:22:00                      153             portão
# 2  2009-01-01 15:59:00                      156             cajuru
# 3  2009-01-01 16:13:00                      156        bairro novo
# 4  2009-01-01 16:29:00                     SIGA        pinheirinho
#
#                              ADDRESS_FINAL
# 0            cic, Curitiba, Parana, Brazil
# 1     fazendinha, Curitiba, Parana, Brazil
# 2        uberaba, Curitiba, Parana, Brazil
# 3  sítio cercado, Curitiba, Parana, Brazil
# 4      tatuquara, Curitiba, Parana, Brazil

# %%
raw_data_grouped = raw_data.groupby("ADDRESS_FINAL")
df_address =  pd.DataFrame(raw_data_grouped)
df_address.drop(1, axis=1, inplace=True)
df_address["location"] = 0
df_address
# Out:
#                                                      0  location
# 0                  abranches, Curitiba, Parana, Brazil         0
# 1                        ahú, Curitiba, Parana, Brazil         0
# 2             alto boqueirão, Curitiba, Parana, Brazil         0
# 3             alto da glória, Curitiba, Parana, Brazil         0
# 4             alto da rua xv, Curitiba, Parana, Brazil         0
# ..                                                 ...       ...
# 126  vila vila maria antonieta, Curitiba, Parana, B...         0
# 127             vista alegre, Curitiba, Parana, Brazil         0
# 128                    xaxim, Curitiba, Parana, Brazil         0
# 129               água verde, Curitiba, Parana, Brazil         0
# 130              águas belas, Curitiba, Parana, Brazil         0
#
# [131 rows x 2 columns]

# %%
from geopy.extra.rate_limiter import RateLimiter

locator = Photon(timeout=20)
geocode = RateLimiter(locator.geocode, min_delay_seconds=1, max_retries=2)
df_address['location'] = df_address[0].apply(geocode)
df_address.head()
# Out:
#                                           0  \
# 0       abranches, Curitiba, Parana, Brazil
# 1             ahú, Curitiba, Parana, Brazil
# 2  alto boqueirão, Curitiba, Parana, Brazil
# 3  alto da glória, Curitiba, Parana, Brazil
# 4  alto da rua xv, Curitiba, Parana, Brazil
#
#                                             location
# 0  (Curitiba, Paraná, Brazil, (-25.4295963, -49.2...
# 1  (Curitiba, Paraná, Brazil, (-25.4295963, -49.2...
# 2  (Córrego Alto Boqueirão, 81770-440, Curitiba, ...
# 3  (Brazil Picante, 1099, Rua Mauá, 80030-150, Ru...
# 4  (Alto da Rua XV, Curitiba, Paraná, Brazil, (-2...

# %%
df_address['point'] = df_address['location'].apply(lambda loc: tuple(loc.point) if loc else None)
df_address[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df_address['point'].tolist(), index=df_address.index)
df_address
# Out:
#                                                      0  \
# 0                  abranches, Curitiba, Parana, Brazil
# 1                        ahú, Curitiba, Parana, Brazil
# 2             alto boqueirão, Curitiba, Parana, Brazil
# 3             alto da glória, Curitiba, Parana, Brazil
# 4             alto da rua xv, Curitiba, Parana, Brazil
# ..                                                 ...
# 126  vila vila maria antonieta, Curitiba, Parana, B...
# 127             vista alegre, Curitiba, Parana, Brazil
# 128                    xaxim, Curitiba, Parana, Brazil
# 129               água verde, Curitiba, Parana, Brazil
# 130              águas belas, Curitiba, Parana, Brazil
#
#                                               location  \
# 0    (Curitiba, Paraná, Brazil, (-25.4295963, -49.2...
# 1    (Curitiba, Paraná, Brazil, (-25.4295963, -49.2...
# 2    (Córrego Alto Boqueirão, 81770-440, Curitiba, ...
# 3    (Brazil Picante, 1099, Rua Mauá, 80030-150, Ru...
# 4    (Alto da Rua XV, Curitiba, Paraná, Brazil, (-2...
# ..                                                 ...
# 126  (Planta Vila Maria I, Curitiba, Paraná, Brazil...
# 127  (Córrego Vista Alegre, 81320-390, Curitiba, Pa...
# 128  (Curitiba, Paraná, Brazil, (-25.4295963, -49.2...
# 129  (Feira Livre do Água Verde, Rua Professor Braz...
# 130  (Águas Belas, São José dos Pinhais, Paraná, Br...
#
#                                        point   latitude  longitude  altitude
# 0            (-25.4295963, -49.2712724, 0.0) -25.429596 -49.271272       0.0
# 1            (-25.4295963, -49.2712724, 0.0) -25.429596 -49.271272       0.0
# 2            (-25.5309106, -49.2290427, 0.0) -25.530911 -49.229043       0.0
# 3              (-25.41651, -49.2646701, 0.0) -25.416510 -49.264670       0.0
# 4            (-25.4280673, -49.2511966, 0.0) -25.428067 -49.251197       0.0
# ..                                       ...        ...        ...       ...
# 126  (-25.4847227, -49.314875433880225, 0.0) -25.484723 -49.314875       0.0
# 127          (-25.4675574, -49.3161516, 0.0) -25.467557 -49.316152       0.0
# 128          (-25.4295963, -49.2712724, 0.0) -25.429596 -49.271272       0.0
# 129          (-25.4629852, -49.2910168, 0.0) -25.462985 -49.291017       0.0
# 130          (-25.5315546, -49.1888154, 0.0) -25.531555 -49.188815       0.0
#
# [131 rows x 6 columns]

# %%
df_address.drop(["location", "point", "altitude"], axis=1, inplace=True)
df_address
# Out:
#                                                      0   latitude  longitude
# 0                  abranches, Curitiba, Parana, Brazil -25.429596 -49.271272
# 1                        ahú, Curitiba, Parana, Brazil -25.429596 -49.271272
# 2             alto boqueirão, Curitiba, Parana, Brazil -25.530911 -49.229043
# 3             alto da glória, Curitiba, Parana, Brazil -25.416510 -49.264670
# 4             alto da rua xv, Curitiba, Parana, Brazil -25.428067 -49.251197
# ..                                                 ...        ...        ...
# 126  vila vila maria antonieta, Curitiba, Parana, B... -25.484723 -49.314875
# 127             vista alegre, Curitiba, Parana, Brazil -25.467557 -49.316152
# 128                    xaxim, Curitiba, Parana, Brazil -25.429596 -49.271272
# 129               água verde, Curitiba, Parana, Brazil -25.462985 -49.291017
# 130              águas belas, Curitiba, Parana, Brazil -25.531555 -49.188815
#
# [131 rows x 3 columns]

# %%
merged_inner = pd.merge(left=raw_data,right=df_address, left_on='ADDRESS_FINAL', right_on=0)
merged_inner.drop([0], axis=1, inplace=True)
merged_inner
# Out:
#        ATENDIMENTO_BAIRRO_NOME  \
# 0                          cic
# 1                          cic
# 2                          cic
# 3                          cic
# 4                          cic
# ...                        ...
# 255911             águas belas
# 255912                 estados
# 255913                jr taisa
# 255914          planta deodoro
# 255915                    maua
#
#                                       NATUREZA1_DESCRICAO  \
# 0                                                 alarmes
# 1                                                 alarmes
# 2                                                 invasão
# 3                                              alagamento
# 4                                                 alarmes
# ...                                                   ...
# 255911                                            escolta
# 255912    violação de medida protetiva lei maria da penha
# 255913                                              apoio
# 255914                                              apoio
# 255915  extravio, sonegação ou inutilização de livro o...
#
#                           SUBCATEGORIA1_DESCRICAO      OCORRENCIA_DATA  \
# 0                               disparo de alarme  2009-01-01 15:14:00
# 1                               disparo de alarme  2009-01-01 19:45:00
# 2       invasão de equipamento/patrimônio público  2009-01-01 20:45:00
# 3                                   não informado  2009-01-01 21:45:00
# 4                               disparo de alarme  2009-01-01 23:46:00
# ...                                           ...                  ...
# 255911                              não informado  2019-08-31 14:00:00
# 255912                              não informado  2019-05-26 15:09:00
# 255913                                apoio ao gm  2019-07-24 22:15:00
# 255914                 apoio ao cidadão - socorro  2019-07-31 10:48:00
# 255915                              não informado  2019-09-05 09:00:00
#
#        ORIGEM_CHAMADO_DESCRICAO    REGIONAL_FATO_NOME  \
# 0                          SIGA                   cic
# 1                          SIGA                   cic
# 2                           190                   cic
# 3                           153                   cic
# 4                          SIGA                   cic
# ...                         ...                   ...
# 255911                   OFÍCIO  região metropolitana
# 255912                 IMEDIATA  região metropolitana
# 255913                  AOS GMS             boa vista
# 255914                     FONE  região metropolitana
# 255915                  AOS GMS             boa vista
#
#                                    ADDRESS_FINAL   latitude  longitude
# 0                  cic, Curitiba, Parana, Brazil -25.429596 -49.271272
# 1                  cic, Curitiba, Parana, Brazil -25.429596 -49.271272
# 2                  cic, Curitiba, Parana, Brazil -25.429596 -49.271272
# 3                  cic, Curitiba, Parana, Brazil -25.429596 -49.271272
# 4                  cic, Curitiba, Parana, Brazil -25.429596 -49.271272
# ...                                          ...        ...        ...
# 255911     águas belas, Curitiba, Parana, Brazil -25.531555 -49.188815
# 255912         estados, Curitiba, Parana, Brazil -25.429596 -49.271272
# 255913        jr taisa, Curitiba, Parana, Brazil -25.233046 -48.826578
# 255914  planta deodoro, Curitiba, Parana, Brazil -25.544439 -49.166721
# 255915            maua, Curitiba, Parana, Brazil -25.416510 -49.264670
#
# [255916 rows x 9 columns]

# %%
map1 = folium.Map(
    location=[59.338315,18.089960],
    tiles='cartodbpositron',
    zoom_start=12,
)
df.apply(lambda row:folium.CircleMarker(location=[row["latitude"], row["longitude"]]).add_to(map1), axis=1)
map1
